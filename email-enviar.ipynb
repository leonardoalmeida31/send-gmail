# %%
import json 
import pandas as pd

from email.mime.multipart import MIMEMultipart
from email.mime.text import MIMEText
import smtplib

import os
os.chdir("C:\\Users\\Leonardo\\Documents\\GitHub\\send-gmail")
emails = pd.read_excel("./emails2.xlsx")

for index, cliente in emails.iterrows():
    # Corpo da mensagem do email #
   msg = MIMEMultipart()
message = """
<!DOCTYPE html>
<html>
<head>
<style>
  /* Estilos para a tabela principal */
  .email-container {
    width: 100%;
    max-width: 1360px; /* Define a largura máxima para garantir que o e-mail seja responsivo em dispositivos menores */
    margin: 0 auto; /* Centraliza a tabela na página */
    padding: 15px;
    border-radius: 7px;
    font-family: Arial, Helvetica, sans-serif;
    background-color: #1C5253; /* Background verde */
    color: #ffffff; /* Texto branco */
  }

  /* Estilos para o cabeçalho */
  .header {
    text-align: center;
    padding: 10px;
  }

  .header img {
    max-width: 100%;
    height: auto;
    border-radius: 7px;
    margin-top: 10px;
  }

  /* Estilos para o corpo do e-mail */
  .email-body {
    background-color: #29797a;
    padding: 20px;
    border-radius: 8px;
    box-shadow: 0px 2px 4px rgba(0, 0, 0, 0.1);
  }
  .email-body2 {
    background-color: #29797a;
    text-align: center;
    padding: 5px;
    border-radius: 8px;
    box-shadow: 0px 2px 4px rgba(0, 0, 0, 0.1);
  }

  .email-body h1 {
    color: #ffffff; /* Texto branco */
    text-align: center;
    margin-top: 0;
  }

  .email-body p {
    font-size: 1.1em;
    margin-bottom: 10px;
  }
  .rodape {
    font-size: 0.800em;
    margin-bottom: 10px;
  }
  .email-body h1 {
    font-size: 0.900em;
    padding: 0.300em;
    text-align: center;
  }
  .button-container {
    text-align: center; /* Centraliza o botão */
  }
  .button {
    display: inline-block;
    background-color: #fc6500;
    color: #ffffff;
    padding: 7px 15px;
    text-align: center;
    font-size: 1em;
    border: 2px solid #fc6500;
    border-radius: 30px;
    transition: background-color 0.3s;
    text-decoration: none; /* Remove sublinhado do link */
  }
  .button a {
    color: inherit; /* Herda a cor do texto do botão */
    text-decoration: none; /* Remove sublinhado do link */
    font-size: 0.900em;
    font-weight: 600;
  }

  .button:hover {
    background-color: #1C5253; /* Background cinza claro ao passar o mouse */
  }

  .signature {
    text-align: center;
    padding-top: 20px;
  }
</style>
</head>
<body>
  <table class="email-container">
    <tr>
        <td class="email-body2">
          <h1>Questões Comentadas do ESTATUTO DA PESSOA IDOSA - 2024 Para Assistentes Sociais</h1>
        </td>
      </tr>
    <tr>
      <td class="header">
        <a href="https://youtu.be/CRk1w3ntR6Q?si=zbcj-_WSzKRRrlNt">
          <img width="560" height="315" src="https://firebasestorage.googleapis.com/v0/b/sesoemconcursosweb.appspot.com/o/imagens%2F_thumb%20PESSOA%20IDOSA%20LEI.png?alt=media&token=3daaa93e-ecf2-4a83-80f9-ec12a9860228" />
        </a>
      </td>
    </tr>
    <tr>
      <td class="email-body">
        <p>Olá, Assistente Social.</p>
        <p>Gravamos hoje um vídeo de Questões comentadas do ESTATUTO DA PESSOA IDOSA só com questões de 2024 que caíram em concursos de Serviço Social.</p>
        <p>Te convido a assistir para estudar conosco e ficar por dentro dos assuntos mais cobrados desse ESTATUTO neste ano. Basta tocar no botão abaixo para assistir</p>
        <div class="button-container">
            <button class="button"><a href="https://youtu.be/CRk1w3ntR6Q?si=zbcj-_WSzKRRrlNt">TOQUE AQUI PARA ASSISTIR</a></button>
          </div>
          <p style="font-size: 0.800em;">Qualquer dúvida, estou à disposição.</p>
          <p style="font-size: 0.800em;">Atenciosamente,</p>
          <p style="font-size: 0.900em;">Leonardo Almeida, do SESO em Concursos</p>
      </td>
    </tr>
  </table>
</body>
</html>
"""
password = 'lsrl gxyh nmsf lsiq'
msg['From'] = 'leonardoalmeidaseso@gmail.com'
msg['To'] = cliente['email']
msg['Subject'] = "Teste - SESO em Concursos1" # Assunto do email
# Monta conexão e envia o email #
msg.attach(MIMEText(message, 'html'))
server = smtplib.SMTP('smtp.gmail.com', port=587)
server.starttls()
server.login(msg['From'], password)
server.sendmail(msg['From'], msg['To'], msg.as_string())
server.quit()
# Out:
# (221,
#  b'2.0.0 closing connection r26-20020a62e41a000000b006e06e418c5esm20622pfh.218 - gsmtp')

# %%
import json 
import pandas as pd
from email.mime.multipart import MIMEMultipart
from email.mime.text import MIMEText
import smtplib
import os

os.chdir("C:\\Users\\Leonardo\\Documents\\GitHub\\send-gmail")
emails = pd.read_excel("./emails-video-teste.xlsx")

password = 'lsrlgxyhnmsflsiq'
sender_email = 'leonardoalmeidaseso@gmail.com'

for index, cliente in emails.iterrows():
    # Corpo da mensagem do email #
    msg = MIMEMultipart()
    message = """
<!DOCTYPE html>
<html>
<head>
<style>
  /* Estilos para a tabela principal */
  .email-container {
    width: 100%;
    max-width: 1360px; /* Define a largura máxima para garantir que o e-mail seja responsivo em dispositivos menores */
    margin: 0 auto; /* Centraliza a tabela na página */
    padding: 15px;
    border-radius: 7px;
    font-family: Arial, Helvetica, sans-serif;
    background-color: #1C5253; /* Background verde */
    color: #ffffff; /* Texto branco */
  }

  /* Estilos para o cabeçalho */
  .header {
    text-align: center;
    padding: 10px;
  }

  .header img {
    max-width: 100%;
    height: auto;
    border-radius: 7px;
    margin-top: 10px;
  }

  /* Estilos para o corpo do e-mail */
  .email-body {
    background-color: #29797a;
    padding: 20px;
    border-radius: 8px;
    box-shadow: 0px 2px 4px rgba(0, 0, 0, 0.1);
  }
  .email-body2 {
    background-color: #29797a;
    text-align: center;
    padding: 5px;
    border-radius: 8px;
    box-shadow: 0px 2px 4px rgba(0, 0, 0, 0.1);
  }

  .email-body h1 {
    color: #ffffff; /* Texto branco */
    text-align: center;
    margin-top: 0;
  }

  .email-body p {
    font-size: 1.1em;
    margin-bottom: 10px;
  }
  .rodape {
    font-size: 0.800em;
    margin-bottom: 10px;
  }
  .email-body h1 {
    font-size: 0.900em;
    padding: 0.300em;
    text-align: center;
  }
  .button-container {
    text-align: center; /* Centraliza o botão */
  }
  .button {
    display: inline-block;
    background-color: #fc6500;
    color: #ffffff;
    padding: 7px 15px;
    text-align: center;
    font-size: 1em;
    border: 2px solid #fc6500;
    border-radius: 30px;
    transition: background-color 0.3s;
    text-decoration: none; /* Remove sublinhado do link */
  }
  .button a {
    color: inherit; /* Herda a cor do texto do botão */
    text-decoration: none; /* Remove sublinhado do link */
    font-size: 0.900em;
    font-weight: 600;
  }

  .button:hover {
    background-color: #1C5253; /* Background cinza claro ao passar o mouse */
  }

  .signature {
    text-align: center;
    padding-top: 20px;
  }
</style>
</head>
<body>
  <table class="email-container">
    <tr>
        <td class="email-body2">
          <h1>Questões Comentadas do ECA 2024 Para Assistentes Sociais</h1>
        </td>
      </tr>
    <tr>
      <td class="header">
        <iframe width="560" height="315" src="https://www.youtube.com/embed/RIXOLpIqSQc?si=0Tnwsw-w-S03YaP0" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" allowfullscreen></iframe>
      </td>
    </tr>
    <tr>
      <td class="email-body">
        <p>Olá, Assistente Social.</p>
        <p>Gravamos hoje um vídeo de Questões comentadas do Estatuto da Criança e do Adolescente só com questões de 2024 que caíram em concursos de Serviço Social.</p>
        <p>Te convido a assistir para estudar conosco e ficar por dentro dos assuntos mais cobrados do ECA neste ano. Basta tocar no vídeo para assistir</p>
        <div class="button-container">
            <button class="button"><a href="https://sesoemconcursos.com.br/">SESOEMCONCURSOS.COM.BR</a></button>
          </div>
          <p style="font-size: 0.800em;">Qualquer dúvida, estou à disposição.</p>
          <p style="font-size: 0.800em;">Atenciosamente,</p>
          <p style="font-size: 0.900em;">Leonardo Almeida, do SESO em Concursos</p>
      </td>
    </tr>
  </table>
</body>
</html>
    """
    msg['From'] = sender_email
    msg['To'] = cliente['email']
    msg['Subject'] = "Assista ao novo vídeo" # Assunto do email
    # Monta conexão e envia o email #
    msg.attach(MIMEText(message, 'html'))
    server = smtplib.SMTP('smtp.gmail.com', port=587)
    server.starttls()
    server.login(msg['From'], password)
    server.sendmail(msg['From'], msg['To'], msg.as_string())
    server.quit()
# Out:
# ---------------------------------------------------------------------------
# SMTPAuthenticationError                   Traceback (most recent call last)
# Cell In[3], line 149
#     147 server = smtplib.SMTP('smtp.gmail.com', port=587)
#     148 server.starttls()
# --> 149 server.login(msg['From'], password)
#     150 server.sendmail(msg['From'], msg['To'], msg.as_string())
#     151 server.quit()
#
# File ~\anaconda3\Lib\smtplib.py:750, in SMTP.login(self, user, password, initial_response_ok)
#     747         last_exception = e
#     749 # We could not login successfully.  Return result of last attempt.
# --> 750 raise last_exception
#
# File ~\anaconda3\Lib\smtplib.py:739, in SMTP.login(self, user, password, initial_response_ok)
#     737 method_name = 'auth_' + authmethod.lower().replace('-', '_')
#     738 try:
# --> 739     (code, resp) = self.auth(
#     740         authmethod, getattr(self, method_name),
#     741         initial_response_ok=initial_response_ok)
# ...

# %%
import json 
import pandas as pd
from email.mime.multipart import MIMEMultipart
from email.mime.text import MIMEText
import smtplib
import os

os.chdir("C:\\Users\\Leonardo\\Documents\\GitHub\\send-gmail")
emails = pd.read_excel("./emails-video-teste.xlsx")

password = '57172544Lv*'
sender_email = 'leonardoalmeidaseso@gmail.com'

for index, cliente in emails.iterrows():
    # Corpo da mensagem do email #
    msg = MIMEMultipart()
    message = """
<!DOCTYPE html>
<html>
<head>
<style>
  /* Estilos para a tabela principal */
  .email-container {
    width: 100%;
    max-width: 1360px; /* Define a largura máxima para garantir que o e-mail seja responsivo em dispositivos menores */
    margin: 0 auto; /* Centraliza a tabela na página */
    padding: 15px;
    border-radius: 7px;
    font-family: Arial, Helvetica, sans-serif;
    background-color: #1C5253; /* Background verde */
    color: #ffffff; /* Texto branco */
  }

  /* Estilos para o cabeçalho */
  .header {
    text-align: center;
    padding: 10px;
  }

  .header img {
    max-width: 100%;
    height: auto;
    border-radius: 7px;
    margin-top: 10px;
  }

  /* Estilos para o corpo do e-mail */
  .email-body {
    background-color: #29797a;
    padding: 20px;
    border-radius: 8px;
    box-shadow: 0px 2px 4px rgba(0, 0, 0, 0.1);
  }
  .email-body2 {
    background-color: #29797a;
    text-align: center;
    padding: 5px;
    border-radius: 8px;
    box-shadow: 0px 2px 4px rgba(0, 0, 0, 0.1);
  }

  .email-body h1 {
    color: #ffffff; /* Texto branco */
    text-align: center;
    margin-top: 0;
  }

  .email-body p {
    font-size: 1.1em;
    margin-bottom: 10px;
  }
  .rodape {
    font-size: 0.800em;
    margin-bottom: 10px;
  }
  .email-body h1 {
    font-size: 0.900em;
    padding: 0.300em;
    text-align: center;
  }
  .button-container {
    text-align: center; /* Centraliza o botão */
  }
  .button {
    display: inline-block;
    background-color: #fc6500;
    color: #ffffff;
    padding: 7px 15px;
    text-align: center;
    font-size: 1em;
    border: 2px solid #fc6500;
    border-radius: 30px;
    transition: background-color 0.3s;
    text-decoration: none; /* Remove sublinhado do link */
  }
  .button a {
    color: inherit; /* Herda a cor do texto do botão */
    text-decoration: none; /* Remove sublinhado do link */
    font-size: 0.900em;
    font-weight: 600;
  }

  .button:hover {
    background-color: #1C5253; /* Background cinza claro ao passar o mouse */
  }

  .signature {
    text-align: center;
    padding-top: 20px;
  }
</style>
</head>
<body>
  <table class="email-container">
    <tr>
        <td class="email-body2">
          <h1>Questões Comentadas do ECA 2024 Para Assistentes Sociais</h1>
        </td>
      </tr>
    <tr>
      <td class="header">
        <iframe width="560" height="315" src="https://www.youtube.com/embed/RIXOLpIqSQc?si=0Tnwsw-w-S03YaP0" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" allowfullscreen></iframe>
      </td>
    </tr>
    <tr>
      <td class="email-body">
        <p>Olá, Assistente Social.</p>
        <p>Gravamos hoje um vídeo de Questões comentadas do Estatuto da Criança e do Adolescente só com questões de 2024 que caíram em concursos de Serviço Social.</p>
        <p>Te convido a assistir para estudar conosco e ficar por dentro dos assuntos mais cobrados do ECA neste ano. Basta tocar no vídeo para assistir</p>
        <div class="button-container">
            <button class="button"><a href="https://sesoemconcursos.com.br/">SESOEMCONCURSOS.COM.BR</a></button>
          </div>
          <p style="font-size: 0.800em;">Qualquer dúvida, estou à disposição.</p>
          <p style="font-size: 0.800em;">Atenciosamente,</p>
          <p style="font-size: 0.900em;">Leonardo Almeida, do SESO em Concursos</p>
      </td>
    </tr>
  </table>
</body>
</html>
    """
    msg['From'] = sender_email
    msg['To'] = cliente['email']
    msg['Subject'] = "Assista ao novo vídeo" # Assunto do email
    # Monta conexão e envia o email #
    msg.attach(MIMEText(message, 'html'))
    server = smtplib.SMTP('smtp.zoho.com', port=587)
    server.starttls()
    server.login(msg['From'], password)
    server.sendmail(msg['From'], msg['To'], msg.as_string())
    server.quit()
# Out:
# ---------------------------------------------------------------------------
# SMTPAuthenticationError                   Traceback (most recent call last)
# Cell In[3], line 149
#     147 server = smtplib.SMTP('smtp.zoho.com', port=587)
#     148 server.starttls()
# --> 149 server.login(msg['From'], password)
#     150 server.sendmail(msg['From'], msg['To'], msg.as_string())
#     151 server.quit()
#
# File ~\anaconda3\Lib\smtplib.py:750, in SMTP.login(self, user, password, initial_response_ok)
#     747         last_exception = e
#     749 # We could not login successfully.  Return result of last attempt.
# --> 750 raise last_exception
#
# File ~\anaconda3\Lib\smtplib.py:739, in SMTP.login(self, user, password, initial_response_ok)
#     737 method_name = 'auth_' + authmethod.lower().replace('-', '_')
#     738 try:
# --> 739     (code, resp) = self.auth(
#     740         authmethod, getattr(self, method_name),
#     741         initial_response_ok=initial_response_ok)
# ...

# %%
pip install schedule
# Out:
# ...
#   Obtaining dependency information for schedule from https://files.pythonhosted.org/packages/f0/1a/e5a65c08d708ee4c002f3f938ba69b2282af478755700c40f037eacc92ef/schedule-1.2.1-py2.py3-none-any.whl.metadata
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
from email.mime.multipart import MIMEMultipart
from email.mime.text import MIMEText
import smtplib
import os

os.chdir("C:\\Users\\Leonardo\\Documents\\GitHub\\send-gmail")
emails = pd.read_excel("./emails-video-1-laudo2.xlsx")

password = 'lsrl gxyh nmsf lsiq'
sender_email = 'leonardoalmeidaseso@gmail.com'
sender_name = 'SESO em Concursos'  # Novo nome do remetente

for index, cliente in emails.iterrows():
    # Corpo da mensagem do email #
    msg = MIMEMultipart()
    message = """
<!DOCTYPE html>
<html>
<head>
<style>
  /* Estilos para a tabela principal */
  .email-container {
    width: 100%;
    max-width: 1360px; /* Define a largura máxima para garantir que o e-mail seja responsivo em dispositivos menores */
    margin: 0 auto; /* Centraliza a tabela na página */
    padding: 15px;
    border-radius: 7px;
    font-family: Arial, Helvetica, sans-serif;
    background-color: #1C5253; /* Background verde */
    color: #ffffff; /* Texto branco */
  }

  /* Estilos para o cabeçalho */
  .header {
    text-align: center;
    padding: 10px;
  }

  .header img {
    max-width: 100%;
    height: auto;
    border-radius: 7px;
    margin-top: 10px;
  }

  /* Estilos para o corpo do e-mail */
  .email-body {
    background-color: #29797a;
    padding: 20px;
    border-radius: 8px;
    box-shadow: 0px 2px 4px rgba(0, 0, 0, 0.1);
  }
  .email-body2 {
    background-color: #29797a;
    text-align: center;
    padding: 5px;
    border-radius: 8px;
    box-shadow: 0px 2px 4px rgba(0, 0, 0, 0.1);
  }

  .email-body h1 {
    color: #ffffff; /* Texto branco */
    text-align: center;
    margin-top: 0;
  }

  .email-body p {
    font-size: 1.1em;
    margin-bottom: 10px;
  }
  .rodape {
    font-size: 0.800em;
    margin-bottom: 10px;
  }
  .email-body h1 {
    font-size: 0.900em;
    padding: 0.300em;
    text-align: center;
  }
  .button-container {
    text-align: center; /* Centraliza o botão */
  }
  .button {
    display: inline-block;
    background-color: #fc6500;
    color: #ffffff;
    padding: 7px 15px;
    text-align: center;
    font-size: 1em;
    border: 2px solid #fc6500;
    border-radius: 30px;
    transition: background-color 0.3s;
    text-decoration: none; /* Remove sublinhado do link */
  }
  .button a {
    color: inherit; /* Herda a cor do texto do botão */
    text-decoration: none; /* Remove sublinhado do link */
    font-size: 0.900em;
    font-weight: 600;
  }

  .button:hover {
    background-color: #1C5253; /* Background cinza claro ao passar o mouse */
  }

  .signature {
    text-align: center;
    padding-top: 20px;
  }
</style>
</head>
<body>
  <table class="email-container">
    <tr>
        <td class="email-body2">
          <h1>Questões Comentadas de Estudo social, perícia, relatório , laudo e parecer  - 2024 Para Assistentes Sociais</h1>
        </td>
      </tr>
    <tr>
      <td class="header">
        <a href="https://www.youtube.com/watch?v=4cMpd5LOvmw&t=6s">
          <img width="560" height="315" src="https://firebasestorage.googleapis.com/v0/b/sesoemconcursosweb.appspot.com/o/imagens%2FC%C3%B3pia%20de%20thumb%20estudo%20social.png?alt=media&token=2db2508c-93da-40c4-9ccb-27a3248446ab" />
        </a>
      </td>
    </tr>
    <tr>
      <td class="email-body">
        <p>Olá, Assistente Social.</p>
        <p>Já está disponível no nosso canal o vídeo de <strong>Questões Comentadas de Estudo social, perícia, relatório , laudo e parecer  - 2024 Para Assistentes Sociais</strong>só com questões de 2024 que caíram em concursos de Serviço Social.</p>
        <p>Te convido a assistir para estudar conosco e ficar por dentro dos assuntos mais cobrados desse assunto neste ano. Basta tocar no botão abaixo para assistir</p>
        <div class="button-container">
            <button class="button"><a href="https://www.youtube.com/watch?v=4cMpd5LOvmw&t=6s">TOQUE AQUI PARA ASSISTIR</a></button>
          </div>
          <p style="font-size: 0.800em;">Qualquer dúvida, estou à disposição.</p>
          <p style="font-size: 0.800em;">Atenciosamente,</p>
          <p style="font-size: 0.900em;">Leonardo Almeida, do SESO em Concursos</p>
      </td>
    </tr>
  </table>
</body>
</html>
    """
    msg['From'] = f"{sender_name} <{sender_email}>"
    msg['To'] = cliente['email']
    msg['Subject'] = "Questões Comentadas de Estudo social, perícia, relatório , laudo e parecer - 2024 Para Assistentes Sociais" # Assunto do email

    # Monta conexão e envia o email #
    msg.attach(MIMEText(message, 'html'))
    
    try:
        server = smtplib.SMTP('smtp.gmail.com', port=587)
        server.starttls()
        server.login(sender_email, password)
        server.sendmail(sender_email, msg['To'], msg.as_string())
        server.quit()
        print(f"E-mail enviado para {msg['To']}")
    except Exception as e:
        print(f"Falha ao enviar e-mail para {msg['To']}: {e}")
# Out:
# E-mail enviado para taticleoflor@gmail.com
# E-mail enviado para leolima1217@gmail.com
# E-mail enviado para fransoarespaz@gmail.com
# E-mail enviado para eufrazinamesquita2@gmail.com
# E-mail enviado para saralicia9@gmail.com
# E-mail enviado para ferrazcarvalho05@gmail.com
# E-mail enviado para andreiximenes79@gmail.com
# E-mail enviado para mayconsales18@gmail.com
# E-mail enviado para dulcy201@gmail.com
# E-mail enviado para luci.vidal93@gmail.com
# E-mail enviado para vanusaperes6@gmail.com
# E-mail enviado para jessykaestar@gmail.com
# E-mail enviado para denisemarcelina97@gmail.com
# E-mail enviado para alicia.almeida03@gmail.com
# E-mail enviado para joycegalves@hotmail.com
# E-mail enviado para emersonalmeidaigt@gmail.com
# E-mail enviado para secicebcaucaia@gmail.com
# E-mail enviado para 278722020@eniac.edu.br
# E-mail enviado para ts.modesto02@gmail.com
# E-mail enviado para suelen.gambeta89@gmail.com
# E-mail enviado para elitfd@gmail.com
# ...
